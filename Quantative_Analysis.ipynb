# %% [markdown]
# # Quantative Analysis
#
# ## Library 설치 필요
#
# - pykrx : 주가 정보 산출 Library
#
#     - pip install pykrx
#
# - dart-fss : open-dart API를 활용하여 재무제표를 활용할 수 있게 해주는 Library
#
# - TA-Lib : 기술적 분석 지표 산출 Library
#
#     1) https://www.lfd.uci.edu/~gohlke/pythonlibs/#ta-lib : 해당 버전의 TA-Lib 다운로드
#
#     2) 다운받은 폴더로 cd 한 후 pip install (파일이름)

# %% [markdown]
# ## 분석 대상 종목
#
# - 건설
#     - 현대건설
#     - GS건설
#     - 삼부토건
# - 화학
#     - LG화학
#     - 진양화학
# - 철강
#     - POSCO
#     - 현대제철
#     - 조선선재
#     - 하이스틸
# - 전기제품
#     - 삼성SDI
#     - 삼화전기
#     - KH 필룩스
# - 조선
#     - 한국조선해양
#     - 대우조선해양
# - 석유와가스
#     - S-Oil
#     - 극동유화
#     - 미창석유
#     - 대성산업
# - 백화점과 일반상점
#     - 롯데쇼핑
#     - 세이브존 I&C
# - 가스유틸리티
#     - 한국가스공사
#     - 서울가스
# - 양방향미디어와 서비스
#     - NAVER
#     - 카카오
# - 제약
#     - 삼성바이오로직스
#     - 한미약품
#     - 동화약품
# - 항공사
#     - 대한항공
# - 반도체와 반도체장비
#     - 삼성전자
#     - 유니퀘스트
# - 호텔, 레스토랑, 레저
#     - 호텔신라
#     - 이월드
# - 비철금속
#     - 고려아연
#     - 삼아알미늄
#     - 조선내화
# - 전자장비와 기기
#     - LG이노텍
#     - 일진머티리얼즈
#     - 써니전자
# - 항공화물운송과 물류
#     - 현대글로비스
#     - 세방
#     - CJ 제일제당
# - 자동차 부품
#     - 현대위아
#     - 계양전기
# - 전기유틸리티
#     - 한국전력
# - 다각화된 통신서비스
#     - KT

# %% [markdown]
# ### NAME : MARKET - TICKER - SECTOR Dictionary Update (WICS 기준)
#
# - WICS 기준
#     - Wise Industry Classification Standard : FnGuide에서 전세계적으로 사용하는 산업분류 기준을 국내에 맞게 만든 주식 업종 분류 기준.
#     - SECTOR는 WICS 소분류를 입력 (NAVER 등 포탈 증권 페이지의 업종 분류도 WICS 기준)
#
# - 주가 정보 DataFrame에 사용되는 맵핑 dictionary 업데이트
#
# - 업데이트된 dictionary 파일은 ./dataset/N_MTS_dict.pkl 로 저장

# %% [markdown]
# ## 주가 관련 데이터 산출
#
# pykrx 라이브러리 사용
#
# 사용법 https://github.com/sharebook-kr/pykrx
#
# - OHLCV data
#     - OPEN : 시가
#     - HIGH : 고가
#     - LOW : 저가
#     - CLOSE : 종가
#     - VOLUME : 거래량
#
# - 1M_CLOSE_STD : 최근 한 달 종가들의 표준편차
#
# - 기본 지표
#     - PER = CLOSE / EPS
#     - PBR = cLOSE / BPS
#     - EPS = 당기순이익 / 발행주식수
#     - BPS = (총자산 - 총부채) / 발행주식수
#     - DIV = DPS / CLOSE
#     - DPS = 배당금 총액 / 발행주식수
#
# - CAPITALIZATION : 시가총액
#
# - NUMB_OF_SHARES : 발행주식수
#
# - 거래원별 순매수거래금액
#     - INSTITUTION(NP) : 기관
#     - CORP(NP) : 기타 법인
#     - INDIVIDUAL(NP) : 개인

# %%
import numpy as np
import pandas as pd
import warnings
import QuantativeAnalysis as qa

warnings.filterwarnings('ignore')

stock_list = ['현대건설', 'LG화학', 'POSCO', '삼성SDI', '한국조선해양', 'S-Oil', '롯데케미칼', '롯데쇼핑', '한국가스공사', 'GS건설', 'SK이노베이션',
              'NAVER', '삼성바이오로직스', '대한항공', '현대제철', '삼성전자', '호텔신라', '고려아연', 'LG이노텍', '한국전력', 'KT', '한전KPS',
              '현대글로비스', 'CJ제일제당', '카카오', '삼부토건', '진양화학', '조선선재', '하이스틸', '삼화전기', 'KH 필룩스', '대우조선해양', '극동유화', 
              '세이브존I&C', '서울가스', '미창석유', '대성산업', '한미약품', '동화약품', '유니퀘스트', '이월드', '삼아알미늄', '조선내화', '일진머티리얼즈', 
              '써니전자', '세방', '현대위아', '계양전기']

df = qa.get_stock_price_data('20171001', '20210228', stock_list)
df
# Out:
# LG화학 OHLCV complete
# POSCO OHLCV complete
# 삼성SDI OHLCV complete
# 한국조선해양 OHLCV complete
# S-Oil OHLCV complete
# 롯데케미칼 OHLCV complete
# 롯데쇼핑 OHLCV complete
# 한국가스공사 OHLCV complete
# GS건설 OHLCV complete
# SK이노베이션 OHLCV complete
# NAVER OHLCV complete
# 삼성바이오로직스 OHLCV complete
# 대한항공 OHLCV complete
# 현대제철 OHLCV complete
# 삼성전자 OHLCV complete
# 호텔신라 OHLCV complete
# 고려아연 OHLCV complete
# LG이노텍 OHLCV complete
# 한국전력 OHLCV complete
# KT OHLCV complete
# 한전KPS OHLCV complete
# 현대글로비스 OHLCV complete
# CJ제일제당 OHLCV complete
# 카카오 OHLCV complete
# 삼부토건 OHLCV complete
# 진양화학 OHLCV complete
# 조선선재 OHLCV complete
# 하이스틸 OHLCV complete
# 삼화전기 OHLCV complete
# KH 필룩스 OHLCV complete
# 대우조선해양 OHLCV complete
# 극동유화 OHLCV complete
# 세이브존I&C OHLCV complete
# 서울가스 OHLCV complete
# 미창석유 OHLCV complete
# 대성산업 OHLCV complete
# 한미약품 OHLCV complete
# 동화약품 OHLCV complete
# 유니퀘스트 OHLCV complete
# 이월드 OHLCV complete
# 삼아알미늄 OHLCV complete
# 조선내화 OHLCV complete
# 일진머티리얼즈 OHLCV complete
# 써니전자 OHLCV complete
# 세방 OHLCV complete
# 현대위아 OHLCV complete
# 계양전기 OHLCV complete
# LG화학 PER data complete
# POSCO PER data complete
# 삼성SDI PER data complete
# 한국조선해양 PER data complete
# S-Oil PER data complete
# 롯데케미칼 PER data complete
# 롯데쇼핑 PER data complete
# 한국가스공사 PER data complete
# GS건설 PER data complete
# SK이노베이션 PER data complete
# NAVER PER data complete
# 삼성바이오로직스 PER data complete
# 대한항공 PER data complete
# 현대제철 PER data complete
# 삼성전자 PER data complete
# 호텔신라 PER data complete
# 고려아연 PER data complete
# LG이노텍 PER data complete
# 한국전력 PER data complete
# KT PER data complete
# 한전KPS PER data complete
# 현대글로비스 PER data complete
# CJ제일제당 PER data complete
# 카카오 PER data complete
# 삼부토건 PER data complete
# 진양화학 PER data complete
# 조선선재 PER data complete
# 하이스틸 PER data complete
# 삼화전기 PER data complete
# KH 필룩스 PER data complete
# 대우조선해양 PER data complete
# 극동유화 PER data complete
# 세이브존I&C PER data complete
# 서울가스 PER data complete
# 미창석유 PER data complete
# 대성산업 PER data complete
# 한미약품 PER data complete
# 동화약품 PER data complete
# 유니퀘스트 PER data complete
# 이월드 PER data complete
# 삼아알미늄 PER data complete
# 조선내화 PER data complete
# 일진머티리얼즈 PER data complete
# 써니전자 PER data complete
# 세방 PER data complete
# 현대위아 PER data complete
# 계양전기 PER data complete
# PER Mapping complete
# PBR Mapping complete
# EPS Mapping complete
# BPS Mapping complete
# DIV Mapping complete
# DPS Mapping complete
# LG화학 CAPITAL data complete
# POSCO CAPITAL data complete
# 삼성SDI CAPITAL data complete
# 한국조선해양 CAPITAL data complete
# S-Oil CAPITAL data complete
# 롯데케미칼 CAPITAL data complete
# 롯데쇼핑 CAPITAL data complete
# 한국가스공사 CAPITAL data complete
# GS건설 CAPITAL data complete
# SK이노베이션 CAPITAL data complete
# NAVER CAPITAL data complete
# 삼성바이오로직스 CAPITAL data complete
# 대한항공 CAPITAL data complete
# 현대제철 CAPITAL data complete
# 삼성전자 CAPITAL data complete
# 호텔신라 CAPITAL data complete
# 고려아연 CAPITAL data complete
# LG이노텍 CAPITAL data complete
# 한국전력 CAPITAL data complete
# KT CAPITAL data complete
# 한전KPS CAPITAL data complete
# 현대글로비스 CAPITAL data complete
# CJ제일제당 CAPITAL data complete
# 카카오 CAPITAL data complete
# 삼부토건 CAPITAL data complete
# 진양화학 CAPITAL data complete
# 조선선재 CAPITAL data complete
# 하이스틸 CAPITAL data complete
# 삼화전기 CAPITAL data complete
# KH 필룩스 CAPITAL data complete
# 대우조선해양 CAPITAL data complete
# 극동유화 CAPITAL data complete
# 세이브존I&C CAPITAL data complete
# 서울가스 CAPITAL data complete
# 미창석유 CAPITAL data complete
# 대성산업 CAPITAL data complete
# 한미약품 CAPITAL data complete
# 동화약품 CAPITAL data complete
# 유니퀘스트 CAPITAL data complete
# 이월드 CAPITAL data complete
# 삼아알미늄 CAPITAL data complete
# 조선내화 CAPITAL data complete
# 일진머티리얼즈 CAPITAL data complete
# 써니전자 CAPITAL data complete
# 세방 CAPITAL data complete
# 현대위아 CAPITAL data complete
# 계양전기 CAPITAL data complete
# CAPITALIZATION Mapping complete
# NUMB_OF_SHARES Mapping complete
# LG화학 NP data complete
# POSCO NP data complete
# 삼성SDI NP data complete
# 한국조선해양 NP data complete
# S-Oil NP data complete
# 롯데케미칼 NP data complete
# 롯데쇼핑 NP data complete
# 한국가스공사 NP data complete
# GS건설 NP data complete
# SK이노베이션 NP data complete
# NAVER NP data complete
# 삼성바이오로직스 NP data complete
# 대한항공 NP data complete
# 현대제철 NP data complete
# 삼성전자 NP data complete
# 호텔신라 NP data complete
# 고려아연 NP data complete
# LG이노텍 NP data complete
# 한국전력 NP data complete
# KT NP data complete
# 한전KPS NP data complete
# 현대글로비스 NP data complete
# CJ제일제당 NP data complete
# 카카오 NP data complete
# 삼부토건 NP data complete
# 진양화학 NP data complete
# 조선선재 NP data complete
# 하이스틸 NP data complete
# 삼화전기 NP data complete
# KH 필룩스 NP data complete
# 대우조선해양 NP data complete
# 극동유화 NP data complete
# 세이브존I&C NP data complete
# 서울가스 NP data complete
# 미창석유 NP data complete
# 대성산업 NP data complete
# 한미약품 NP data complete
# 동화약품 NP data complete
# 유니퀘스트 NP data complete
# 이월드 NP data complete
# 삼아알미늄 NP data complete
# 조선내화 NP data complete
# 일진머티리얼즈 NP data complete
# 써니전자 NP data complete
# 세방 NP data complete
# 현대위아 NP data complete
# 계양전기 NP data complete
# INSTITUTION(NP) Mapping complete
# CORP(NP) Mapping complete
# INDIVIDUAL(NP) Mapping complete
# FOREIGN(NP) Mapping complete
#             DATE  NAME SECTOR   OPEN   HIGH    LOW  CLOSE   VOLUME  \
# 0     2017-10-10  현대건설     건설  38350  38700  37350  37650   436016
# 1     2017-10-11  현대건설     건설  37550  37800  37350  37450   396581
# 2     2017-10-12  현대건설     건설  37650  40150  37650  39900  1101121
# 3     2017-10-13  현대건설     건설  39900  40250  38900  39050   548941
# 4     2017-10-16  현대건설     건설  39200  39700  38600  39550   325083
# ...          ...   ...    ...    ...    ...    ...    ...      ...
# 39979 2021-02-22  계양전기  자동차부품   5030   5080   4900   4950   631718
# 39980 2021-02-23  계양전기  자동차부품   4895   4895   4710   4710   458610
# 39981 2021-02-24  계양전기  자동차부품   4735   4820   4560   4560   493301
# 39982 2021-02-25  계양전기  자동차부품   4655   4680   4555   4610   232616
# 39983 2021-02-26  계양전기  자동차부품   4480   4565   4380   4450   360085
#
#        1M_CLOSE_STD      PER  ...   EPS    BPS   DIV  DPS  CAPITALIZATION  \
# 0          0.000000     8.55  ...  4403  56944  1.33  500   4192544552250
# 1          0.000000     8.51  ...  4403  56944  1.34  500   4170273399250
# 2          0.000000     9.06  ...  4403  56944  1.25  500   4443095023500
# 3          0.000000     8.87  ...  4403  56944  1.28  500   4348442623250
# 4          0.000000     8.98  ...  4403  56944  1.26  500   4404120505750
# ...             ...      ...  ...   ...    ...   ...  ...             ...
# 39979    204.184200  1237.50  ...     4   5425  0.71   35    161370000000
# 39980    204.532394  1177.50  ...     4   5425  0.74   35    153546000000
# 39981    204.231039  1140.00  ...     4   5425  0.77   35    148656000000
# 39982    201.756747  1152.50  ...     4   5425  0.76   35    150286000000
# 39983    210.200121  1112.50  ...     4   5425  0.79   35    145070000000
#
#        NUMB_OF_SHARES  INSTITUTION(NP)   CORP(NP)  INDIVIDUAL(NP)  FOREIGN(NP)
# 0           111355765      -4772067750  -23761100      2622048700   2173780150
# 1           111355765      -6560995050  -22273750      4865588050   1717680750
# 2           111355765       5587452550   -8327300    -12323171150   6744045900
# 3           111355765       2458753000  141256300      5509351800  -8109361100
# 4           111355765       3461068350 -198450600      -423978200  -2838639550
# ...               ...              ...        ...             ...          ...
# 39979        32600000            -4955          0       -83283130     83288085
# 39980        32600000          4784025          0       -92952560     88168535
# 39981        32600000           325430          0        90131510    -90456940
# 39982        32600000            80140     -37240       -26162810     26119910
# 39983        32600000          1170125   -4667520       -37218070     40715465
#
# [39984 rows x 21 columns]

# %% [markdown]
# ## 재무비율 산출
#
# dart-fss 라이브러리 사용
#
# 사용법 : https://dart-fss.readthedocs.io/en/v0.2.4/welcome.html
#
# - 성장성
#     - 총자산 증가율 (ASST_INC) = (당기 자산총계 / 전기 자산총계 - 1) * 100
#     - 매출액 증가율 (REV_INC) = (당기 매출액 / 전기 매출액 - 1) * 100
#     - 당기순이익 증가율 (PROF_INC) = (당기순이익 / 전기 당기순이익 - 1) * 100
#     - 자기자본 증가율 (S_ASST_INC) = (당기 자기자본 / 전기 매출액 - 1) * 100
#
# - 수익성
#     - 매출액 영업이익률 (REV_BPR) = (영업이익 / 매출액) * 100
#     - 매출액 순이익률 (REV_NPR) = (당기순이익 / 매출액) * 100
#     - 총자본 순이익률 (EQ_NPR) = (당기순이익 / 총자본) * 100
#     - 경영자산 영업이익률 (RA_BPR) = (영업이익 / 경영자산) * 100 ; 경영자산 = 운전자본 = (유동자산 - 유동부채)
#
# - 안전성
#     - 유동비율 (R_RATIO) = (유동자산 / 유동부채) * 100
#     - 당좌비율 (D_RATIO) = {(유동자산 - 재고자산) / 유동부채} * 100
#     - 고정비율 (F_RATIO) = (비유동자산 / 자기자본) * 100
#     - 부채비율 (DEBT_R) = (부채 / 자기자본) * 100
#
# - 활동성
#     - 총자본 회전율 (ASST_TO) = 매출액 / 총자본
#     - 매출채권 회전율 (SA_C_TO) = 매출액 / 매출채권
#     - 재고자산 회전율 (ST_TO) = 매출액 / 재고자산

# %%
from QuantativeAnalysis import FinancialStatements

fs = FinancialStatements('./fsdata/')
fs_df = fs.mapping_fsr(df)
fs_df
# Out:
# ncial Ratio creation complete
# 한국콜마 20180331 Financial Ratio creation complete
# 한국콜마 20171231 Financial Ratio creation complete
# 한국콜마 20170930 Financial Ratio creation complete
# 동일고무벨트 20201231 Financial Ratio creation complete
# 동일고무벨트 20200930 Financial Ratio creation complete
# 동일고무벨트 20200630 Financial Ratio creation complete
# 동일고무벨트 20200331 Financial Ratio creation complete
# 동일고무벨트 20191231 Financial Ratio creation complete
# 동일고무벨트 20190930 Financial Ratio creation complete
# 동일고무벨트 20190630 Financial Ratio creation complete
# 동일고무벨트 20190331 Financial Ratio creation complete
# 동일고무벨트 20181231 Financial Ratio creation complete
# 동일고무벨트 20180930 Financial Ratio creation complete
# 동일고무벨트 20180630 Financial Ratio creation complete
# 동일고무벨트 20180331 Financial Ratio creation complete
# 동일고무벨트 20171231 Financial Ratio creation complete
# 동일고무벨트 20170930 Financial Ratio creation complete
# 동아에스티 20201231 Financial Ratio creation complete
# 동아에스티 20200930 Financial Ratio creation complete
# 동아에스티 20200630 Financial Ratio creation complete
# 동아에스티 20200331 Financial Ratio creation complete
# 동아에스티 20191231 Financial Ratio creation complete
# 동아에스티 20190930 Financial Ratio creation complete
# 동아에스티 20190630 Financial Ratio creation complete
# 동아에스티 20190331 Financial Ratio creation complete
# 동아에스티 20181231 Financial Ratio creation complete
# 동아에스티 20180930 Financial Ratio creation complete
# 동아에스티 20180630 Financial Ratio creation complete
# 동아에스티 20180331 Financial Ratio creation complete
# 동아에스티 20171231 Financial Ratio creation complete
# 동아에스티 20170930 Financial Ratio creation complete
# 하이골드12호 20201231 Financial Ratio creation complete
# 하이골드12호 20200930 Financial Ratio creation complete
# 하이골드12호 20200630 Financial Ratio creation complete
# 하이골드12호 20200331 Financial Ratio creation complete
# 하이골드12호 20191231 Financial Ratio creation complete
# 하이골드12호 20190930 Financial Ratio creation complete
# 하이골드12호 20190630 Financial Ratio creation complete
# 하이골드12호 20190331 Financial Ratio creation complete
# 하이골드12호 20181231 Financial Ratio creation complete
# 하이골드12호 20180930 Financial Ratio creation complete
# 하이골드12호 20180630 Financial Ratio creation complete
# 하이골드12호 20180331 Financial Ratio creation complete
# 하이골드12호 20171231 Financial Ratio creation complete
# 하이골드12호 20170930 Financial Ratio creation complete
# 한진칼 20201231 Financial Ratio creation complete
# 한진칼 20200930 Financial Ratio creation complete
# 한진칼 20200630 Financial Ratio creation complete
# 한진칼 20200331 Financial Ratio creation complete
# 한진칼 20191231 Financial Ratio creation complete
# 한진칼 20190930 Financial Ratio creation complete
# 한진칼 20190630 Financial Ratio creation complete
# 한진칼 20190331 Financial Ratio creation complete
# 한진칼 20181231 Financial Ratio creation complete
# 한진칼 20180930 Financial Ratio creation complete
# 한진칼 20180630 Financial Ratio creation complete
# 한진칼 20180331 Financial Ratio creation complete
# 한진칼 20171231 Financial Ratio creation complete
# 한진칼 20170930 Financial Ratio creation complete
# NHN 20201231 Financial Ratio creation complete
# NHN 20200930 Financial Ratio creation complete
# NHN 20200630 Financial Ratio creation complete
# NHN 20200331 Financial Ratio creation complete
# NHN 20191231 Financial Ratio creation complete
# NHN 20190930 Financial Ratio creation complete
# NHN 20190630 Financial Ratio creation complete
# NHN 20190331 Financial Ratio creation complete
# NHN 20181231 Financial Ratio creation complete
# NHN 20180930 Financial Ratio creation complete
# NHN 20180630 Financial Ratio creation complete
# NHN 20180331 Financial Ratio creation complete
# NHN 20171231 Financial Ratio creation complete
# NHN 20170930 Financial Ratio creation complete
# 아세아시멘트 20201231 Financial Ratio creation complete
# 아세아시멘트 20200930 Financial Ratio creation complete
# 아세아시멘트 20200630 Financial Ratio creation complete
# 아세아시멘트 20200331 Financial Ratio creation complete
# 아세아시멘트 20191231 Financial Ratio creation complete
# 아세아시멘트 20190930 Financial Ratio creation complete
# 아세아시멘트 20190630 Financial Ratio creation complete
# 아세아시멘트 20190331 Financial Ratio creation complete
# 아세아시멘트 20181231 Financial Ratio creation complete
# 아세아시멘트 20180930 Financial Ratio creation complete
# 아세아시멘트 20180630 Financial Ratio creation complete
# 아세아시멘트 20180331 Financial Ratio creation complete
# 아세아시멘트 20171231 Financial Ratio creation complete
# 아세아시멘트 20170930 Financial Ratio creation complete
# 종근당 20201231 Financial Ratio creation complete
# 종근당 20200930 Financial Ratio creation complete
# 종근당 20200630 Financial Ratio creation complete
# 종근당 20200331 Financial Ratio creation complete
# 종근당 20191231 Financial Ratio creation complete
# 종근당 20190930 Financial Ratio creation complete
# 종근당 20190630 Financial Ratio creation complete
# 종근당 20190331 Financial Ratio creation complete
# 종근당 20181231 Financial Ratio creation complete
# 종근당 20180930 Financial Ratio creation complete
# 종근당 20180630 Financial Ratio creation complete
# 종근당 20180331 Financial Ratio creation complete
# 종근당 20171231 Financial Ratio creation complete
# 종근당 20170930 Financial Ratio creation complete
# 코스맥스 20201231 Financial Ratio creation complete
# 코스맥스 20200930 Financial Ratio creation complete
# 코스맥스 20200630 Financial Ratio creation complete
# 코스맥스 20200331 Financial Ratio creation complete
# 코스맥스 20191231 Financial Ratio creation complete
# 코스맥스 20190930 Financial Ratio creation complete
# 코스맥스 20190630 Financial Ratio creation complete
# 코스맥스 20190331 Financial Ratio creation complete
# 코스맥스 20181231 Financial Ratio creation complete
# 코스맥스 20180930 Financial Ratio creation complete
# 코스맥스 20180630 Financial Ratio creation complete
# 코스맥스 20180331 Financial Ratio creation complete
# 코스맥스 20171231 Financial Ratio creation complete
# 코스맥스 20170930 Financial Ratio creation complete
# 제이에스코퍼레이션 20201231 Financial Ratio creation complete
# 제이에스코퍼레이션 20200930 Financial Ratio creation complete
# 제이에스코퍼레이션 20200630 Financial Ratio creation complete
# 제이에스코퍼레이션 20200331 Financial Ratio creation complete
# 제이에스코퍼레이션 20191231 Financial Ratio creation complete
# 제이에스코퍼레이션 20190930 Financial Ratio creation complete
# 제이에스코퍼레이션 20190630 Financial Ratio creation complete
# 제이에스코퍼레이션 20190331 Financial Ratio creation complete
# 제이에스코퍼레이션 20181231 Financial Ratio creation complete
# 제이에스코퍼레이션 20180930 Financial Ratio creation complete
# 제이에스코퍼레이션 20180630 Financial Ratio creation complete
# 제이에스코퍼레이션 20180331 Financial Ratio creation complete
# 제이에스코퍼레이션 20171231 Financial Ratio creation complete
# 제이에스코퍼레이션 20170930 Financial Ratio creation complete
# 해성디에스 20201231 Financial Ratio creation complete
# 해성디에스 20200930 Financial Ratio creation complete
# 해성디에스 20200630 Financial Ratio creation complete
# 해성디에스 20200331 Financial Ratio creation complete
# 해성디에스 20191231 Financial Ratio creation complete
# 해성디에스 20190930 Financial Ratio creation complete
# 해성디에스 20190630 Financial Ratio creation complete
# 해성디에스 20190331 Financial Ratio creation complete
# 해성디에스 20181231 Financial Ratio creation complete
# 해성디에스 20180930 Financial Ratio creation complete
# 해성디에스 20180630 Financial Ratio creation complete
# 해성디에스 20180331 Financial Ratio creation complete
# 해성디에스 20171231 Financial Ratio creation complete
# 해성디에스 20170930 Financial Ratio creation complete
# 서연이화 20201231 Financial Ratio creation complete
# 서연이화 20200930 Financial Ratio creation complete
# 서연이화 20200630 Financial Ratio creation complete
# 서연이화 20200331 Financial Ratio creation complete
# 서연이화 20191231 Financial Ratio creation complete
# 서연이화 20190930 Financial Ratio creation complete
# 서연이화 20190630 Financial Ratio creation complete
# 서연이화 20190331 Financial Ratio creation complete
# 서연이화 20181231 Financial Ratio creation complete
# 서연이화 20180930 Financial Ratio creation complete
# 서연이화 20180630 Financial Ratio creation complete
# 서연이화 20180331 Financial Ratio creation complete
# 서연이화 20171231 Financial Ratio creation complete
# 서연이화 20170930 Financial Ratio creation complete
# 모두투어리츠 20201231 Financial Ratio creation complete
# 모두투어리츠 20200930 Financial Ratio creation complete
# 모두투어리츠 20200630 Financial Ratio creation complete
# 모두투어리츠 20200331 Financial Ratio creation complete
# 모두투어리츠 20191231 Financial Ratio creation complete
# 모두투어리츠 20190930 Financial Ratio creation complete
# 모두투어리츠 20190630 Financial Ratio creation complete
# 모두투어리츠 20190331 Financial Ratio creation complete
# 모두투어리츠 20181231 Financial Ratio creation complete
# 모두투어리츠 20180930 Financial Ratio creation complete
# 모두투어리츠 20180630 Financial Ratio creation complete
# 모두투어리츠 20180331 Financial Ratio creation complete
# 모두투어리츠 20171231 Financial Ratio creation complete
# 모두투어리츠 20170930 Financial Ratio creation complete
# 만도 20201231 Financial Ratio creation complete
# 만도 20200930 Financial Ratio creation complete
# 만도 20200630 Financial Ratio creation complete
# 만도 20200331 Financial Ratio creation complete
# 만도 20191231 Financial Ratio creation complete
# 만도 20190930 Financial Ratio creation complete
# 만도 20190630 Financial Ratio creation complete
# 만도 20190331 Financial Ratio creation complete
# 만도 20181231 Financial Ratio creation complete
# 만도 20180930 Financial Ratio creation complete
# 만도 20180630 Financial Ratio creation complete
# 만도 20180331 Financial Ratio creation complete
# 만도 20171231 Financial Ratio creation complete
# 만도 20170930 Financial Ratio creation complete
# 삼성바이오로직스 20201231 Financial Ratio creation complete
# 삼성바이오로직스 20200930 Financial Ratio creation complete
# 삼성바이오로직스 20200630 Financial Ratio creation complete
# 삼성바이오로직스 20200331 Financial Ratio creation complete
# 삼성바이오로직스 20191231 Financial Ratio creation complete
# 삼성바이오로직스 20190930 Financial Ratio creation complete
# 삼성바이오로직스 20190630 Financial Ratio creation complete
# 삼성바이오로직스 20190331 Financial Ratio creation complete
# 삼성바이오로직스 20181231 Financial Ratio creation complete
# 삼성바이오로직스 20180930 Financial Ratio creation complete
# 삼성바이오로직스 20180630 Financial Ratio creation complete
# 삼성바이오로직스 20180331 Financial Ratio creation complete
# 삼성바이오로직스 20171231 Financial Ratio creation complete
# 삼성바이오로직스 20170930 Financial Ratio creation complete
# 디와이파워 20201231 Financial Ratio creation complete
# 디와이파워 20200930 Financial Ratio creation complete
# 디와이파워 20200630 Financial Ratio creation complete
# 디와이파워 20200331 Financial Ratio creation complete
# 디와이파워 20191231 Financial Ratio creation complete
# 디와이파워 20190930 Financial Ratio creation complete
# 디와이파워 20190630 Financial Ratio creation complete
# 디와이파워 20190331 Financial Ratio creation complete
# 디와이파워 20181231 Financial Ratio creation complete
# 디와이파워 20180930 Financial Ratio creation complete
# 디와이파워 20180630 Financial Ratio creation complete
# 디와이파워 20180331 Financial Ratio creation complete
# 디와이파워 20171231 Financial Ratio creation complete
# 디와이파워 20170930 Financial Ratio creation complete
# SK디앤디 20201231 Financial Ratio creation complete
# SK디앤디 20200930 Financial Ratio creation complete
# SK디앤디 20200630 Financial Ratio creation complete
# SK디앤디 20200331 Financial Ratio creation complete
# SK디앤디 20191231 Financial Ratio creation complete
# SK디앤디 20190930 Financial Ratio creation complete
# SK디앤디 20190630 Financial Ratio creation complete
# SK디앤디 20190331 Financial Ratio creation complete
# SK디앤디 20181231 Financial Ratio creation complete
# SK디앤디 20180930 Financial Ratio creation complete
# SK디앤디 20180630 Financial Ratio creation complete
# SK디앤디 20180331 Financial Ratio creation complete
# SK디앤디 20171231 Financial Ratio creation complete
# SK디앤디 20170930 Financial Ratio creation complete
# 한솔제지 20201231 Financial Ratio creation complete
# 한솔제지 20200930 Financial Ratio creation complete
# 한솔제지 20200630 Financial Ratio creation complete
# 한솔제지 20200331 Financial Ratio creation complete
# 한솔제지 20191231 Financial Ratio creation complete
# 한솔제지 20190930 Financial Ratio creation complete
# 한솔제지 20190630 Financial Ratio creation complete
# 한솔제지 20190331 Financial Ratio creation complete
# 한솔제지 20181231 Financial Ratio creation complete
# 한솔제지 20180930 Financial Ratio creation complete
# 한솔제지 20180630 Financial Ratio creation complete
# 한솔제지 20180331 Financial Ratio creation complete
# 한솔제지 20171231 Financial Ratio creation complete
# 한솔제지 20170930 Financial Ratio creation complete
# 이노션 20201231 is None
# 이노션 20200930 Financial Ratio creation complete
# 이노션 20200630 Financial Ratio creation complete
# 이노션 20200331 Financial Ratio creation complete
# 이노션 20191231 Financial Ratio creation complete
# 이노션 20190930 Financial Ratio creation complete
# 이노션 20190630 Financial Ratio creation complete
# 이노션 20190331 Financial Ratio creation complete
# 이노션 20181231 Financial Ratio creation complete
# 이노션 20180930 Financial Ratio creation complete
# 이노션 20180630 Financial Ratio creation complete
# 이노션 20180331 Financial Ratio creation complete
# 이노션 20171231 Financial Ratio creation complete
# 이노션 20170930 Financial Ratio creation complete
# 금호에이치티 20201231 Financial Ratio creation complete
# 금호에이치티 20200930 Financial Ratio creation complete
# 금호에이치티 20200630 Financial Ratio creation complete
# 금호에이치티 20200331 Financial Ratio creation complete
# 금호에이치티 20191231 Financial Ratio creation complete
# 금호에이치티 20190930 Financial Ratio creation complete
# 금호에이치티 20190630 Financial Ratio creation complete
# 금호에이치티 20190331 Financial Ratio creation complete
# 금호에이치티 20181231 Financial Ratio creation complete
# 금호에이치티 20180930 Financial Ratio creation complete
# 금호에이치티 20180630 Financial Ratio creation complete
# 금호에이치티 20180331 Financial Ratio creation complete
# 금호에이치티 20171231 Financial Ratio creation complete
# 금호에이치티 20170930 Financial Ratio creation complete
# 경보제약 20201231 Financial Ratio creation complete
# 경보제약 20200930 Financial Ratio creation complete
# 경보제약 20200630 Financial Ratio creation complete
# 경보제약 20200331 Financial Ratio creation complete
# 경보제약 20191231 Financial Ratio creation complete
# 경보제약 20190930 Financial Ratio creation complete
# 경보제약 20190630 Financial Ratio creation complete
# 경보제약 20190331 Financial Ratio creation complete
# 경보제약 20181231 Financial Ratio creation complete
# 경보제약 20180930 Financial Ratio creation complete
# 경보제약 20180630 Financial Ratio creation complete
# 경보제약 20180331 Financial Ratio creation complete
# 경보제약 20171231 Financial Ratio creation complete
# 경보제약 20170930 Financial Ratio creation complete
# 토니모리 20201231 Financial Ratio creation complete
# 토니모리 20200930 Financial Ratio creation complete
# 토니모리 20200630 Financial Ratio creation complete
# 토니모리 20200331 Financial Ratio creation complete
# 토니모리 20191231 Financial Ratio creation complete
# 토니모리 20190930 Financial Ratio creation complete
# 토니모리 20190630 Financial Ratio creation complete
# 토니모리 20190331 Financial Ratio creation complete
# 토니모리 20181231 Financial Ratio creation complete
# 토니모리 20180930 Financial Ratio creation complete
# 토니모리 20180630 Financial Ratio creation complete
# 토니모리 20180331 Financial Ratio creation complete
# 토니모리 20171231 Financial Ratio creation complete
# 토니모리 20170930 Financial Ratio creation complete
# 잇츠한불 20201231 Financial Ratio creation complete
# 잇츠한불 20200930 Financial Ratio creation complete
# 잇츠한불 20200630 Financial Ratio creation complete
# 잇츠한불 20200331 Financial Ratio creation complete
# 잇츠한불 20191231 Financial Ratio creation complete
# 잇츠한불 20190930 Financial Ratio creation complete
# 잇츠한불 20190630 Financial Ratio creation complete
# 잇츠한불 20190331 Financial Ratio creation complete
# 잇츠한불 20181231 Financial Ratio creation complete
# 잇츠한불 20180930 Financial Ratio creation complete
# 잇츠한불 20180630 Financial Ratio creation complete
# 잇츠한불 20180331 Financial Ratio creation complete
# 잇츠한불 20171231 Financial Ratio creation complete
# 잇츠한불 20170930 Financial Ratio creation complete
# LS전선아시아 20201231 Financial Ratio creation complete
# LS전선아시아 20200930 Financial Ratio creation complete
# LS전선아시아 20200630 Financial Ratio creation complete
# LS전선아시아 20200331 Financial Ratio creation complete
# LS전선아시아 20191231 Financial Ratio creation complete
# LS전선아시아 20190930 Financial Ratio creation complete
# LS전선아시아 20190630 Financial Ratio creation complete
# LS전선아시아 20190331 Financial Ratio creation complete
# LS전선아시아 20181231 Financial Ratio creation complete
# LS전선아시아 20180930 Financial Ratio creation complete
# LS전선아시아 20180630 Financial Ratio creation complete
# LS전선아시아 20180331 Financial Ratio creation complete
# LS전선아시아 20171231 Financial Ratio creation complete
# LS전선아시아 20170930 Financial Ratio creation complete
# JW생명과학 20201231 Financial Ratio creation complete
# JW생명과학 20200930 Financial Ratio creation complete
# JW생명과학 20200630 Financial Ratio creation complete
# JW생명과학 20200331 Financial Ratio creation complete
# JW생명과학 20191231 Financial Ratio creation complete
# JW생명과학 20190930 Financial Ratio creation complete
# JW생명과학 20190630 Financial Ratio creation complete
# JW생명과학 20190331 Financial Ratio creation complete
# JW생명과학 20181231 Financial Ratio creation complete
# JW생명과학 20180930 Financial Ratio creation complete
# JW생명과학 20180630 Financial Ratio creation complete
# JW생명과학 20180331 Financial Ratio creation complete
# JW생명과학 20171231 Financial Ratio creation complete
# JW생명과학 20170930 Financial Ratio creation complete
# 두산밥캣 20201231 Financial Ratio creation complete
# 두산밥캣 20200930 Financial Ratio creation complete
# 두산밥캣 20200630 Financial Ratio creation complete
# 두산밥캣 20200331 Financial Ratio creation complete
# 두산밥캣 20191231 Financial Ratio creation complete
# 두산밥캣 20190930 Financial Ratio creation complete
# 두산밥캣 20190630 Financial Ratio creation complete
# 두산밥캣 20190331 Financial Ratio creation complete
# 두산밥캣 20181231 Financial Ratio creation complete
# 두산밥캣 20180930 Financial Ratio creation complete
# 두산밥캣 20180630 Financial Ratio creation complete
# 두산밥캣 20180331 Financial Ratio creation complete
# 두산밥캣 20171231 Financial Ratio creation complete
# 두산밥캣 20170930 Financial Ratio creation complete
# 화승엔터프라이즈 20201231 Financial Ratio creation complete
# 화승엔터프라이즈 20200930 Financial Ratio creation complete
# 화승엔터프라이즈 20200630 Financial Ratio creation complete
# 화승엔터프라이즈 20200331 Financial Ratio creation complete
# 화승엔터프라이즈 20191231 Financial Ratio creation complete
# 화승엔터프라이즈 20190930 Financial Ratio creation complete
# 화승엔터프라이즈 20190630 Financial Ratio creation complete
# 화승엔터프라이즈 20190331 Financial Ratio creation complete
# 화승엔터프라이즈 20181231 Financial Ratio creation complete
# 화승엔터프라이즈 20180930 Financial Ratio creation complete
# 화승엔터프라이즈 20180630 Financial Ratio creation complete
# 화승엔터프라이즈 20180331 Financial Ratio creation complete
# 화승엔터프라이즈 20171231 Financial Ratio creation complete
# 화승엔터프라이즈 20170930 Financial Ratio creation complete
# 샘표식품 20201231 Financial Ratio creation complete
# 샘표식품 20200930 Financial Ratio creation complete
# 샘표식품 20200630 Financial Ratio creation complete
# 샘표식품 20200331 Financial Ratio creation complete
# 샘표식품 20191231 Financial Ratio creation complete
# 샘표식품 20190930 Financial Ratio creation complete
# 샘표식품 20190630 Financial Ratio creation complete
# 샘표식품 20190331 Financial Ratio creation complete
# 샘표식품 20181231 Financial Ratio creation complete
# 샘표식품 20180930 Financial Ratio creation complete
# 샘표식품 20180630 Financial Ratio creation complete
# 샘표식품 20180331 Financial Ratio creation complete
# 샘표식품 20171231 Financial Ratio creation complete
# 샘표식품 20170930 Financial Ratio creation complete
# 일동제약 20201231 Financial Ratio creation complete
# 일동제약 20200930 Financial Ratio creation complete
# 일동제약 20200630 Financial Ratio creation complete
# 일동제약 20200331 Financial Ratio creation complete
# 일동제약 20191231 Financial Ratio creation complete
# 일동제약 20190930 Financial Ratio creation complete
# 일동제약 20190630 Financial Ratio creation complete
# 일동제약 20190331 Financial Ratio creation complete
# 일동제약 20181231 Financial Ratio creation complete
# 일동제약 20180930 Financial Ratio creation complete
# 일동제약 20180630 Financial Ratio creation complete
# 일동제약 20180331 Financial Ratio creation complete
# 일동제약 20171231 Financial Ratio creation complete
# 일동제약 20170930 Financial Ratio creation complete
# 넷마블 20201231 Financial Ratio creation complete
# 넷마블 20200930 Financial Ratio creation complete
# 넷마블 20200630 Financial Ratio creation complete
# 넷마블 20200331 Financial Ratio creation complete
# 넷마블 20191231 Financial Ratio creation complete
# 넷마블 20190930 Financial Ratio creation complete
# 넷마블 20190630 Financial Ratio creation complete
# 넷마블 20190331 Financial Ratio creation complete
# 넷마블 20181231 Financial Ratio creation complete
# 넷마블 20180930 Financial Ratio creation complete
# 넷마블 20180630 Financial Ratio creation complete
# 넷마블 20180331 Financial Ratio creation complete
# 넷마블 20171231 Financial Ratio creation complete
# 넷마블 20170930 Financial Ratio creation complete
#              DATE  NAME SECTOR   OPEN   HIGH    LOW  CLOSE   VOLUME  \
# 0      2017-10-10  현대건설     건설  38350  38700  37350  37650   436016
# 1      2017-10-11  현대건설     건설  37550  37800  37350  37450   396581
# 2      2017-10-12  현대건설     건설  37650  40150  37650  39900  1101121
# 3      2017-10-13  현대건설     건설  39900  40250  38900  39050   548941
# 4      2017-10-16  현대건설     건설  39200  39700  38600  39550   325083
# ...           ...   ...    ...    ...    ...    ...    ...      ...
# 39979  2021-02-22  계양전기  자동차부품   5030   5080   4900   4950   631718
# 39980  2021-02-23  계양전기  자동차부품   4895   4895   4710   4710   458610
# 39981  2021-02-24  계양전기  자동차부품   4735   4820   4560   4560   493301
# 39982  2021-02-25  계양전기  자동차부품   4655   4680   4555   4610   232616
# 39983  2021-02-26  계양전기  자동차부품   4480   4565   4380   4450   360085
#
#        1M_CLOSE_STD      PER  ...  REV_BPR  EQ_NPR  RA_BPR  R_RATIO  D_RATIO  \
# 0          0.000000     8.55  ...      NaN     NaN     NaN      NaN      NaN
# 1          0.000000     8.51  ...      NaN     NaN     NaN      NaN      NaN
# 2          0.000000     9.06  ...      NaN     NaN     NaN      NaN      NaN
# 3          0.000000     8.87  ...      NaN     NaN     NaN      NaN      NaN
# 4          0.000000     8.98  ...      NaN     NaN     NaN      NaN      NaN
# ...             ...      ...  ...      ...     ...     ...      ...      ...
# 39979    204.184200  1237.50  ...      NaN     NaN     NaN      NaN      NaN
# 39980    204.532394  1177.50  ...      NaN     NaN     NaN      NaN      NaN
# 39981    204.231039  1140.00  ...      NaN     NaN     NaN      NaN      NaN
# 39982    201.756747  1152.50  ...      NaN     NaN     NaN      NaN      NaN
# 39983    210.200121  1112.50  ...      NaN     NaN     NaN      NaN      NaN
#
#        F_RATIO  DEBT_R  ASST_TO  SA_C_TO  ST_TO
# 0          NaN     NaN      NaN     None    NaN
# 1          NaN     NaN      NaN     None    NaN
# 2          NaN     NaN      NaN     None    NaN
# 3          NaN     NaN      NaN     None    NaN
# 4          NaN     NaN      NaN     None    NaN
# ...        ...     ...      ...      ...    ...
# 39979      NaN     NaN      NaN     None    NaN
# 39980      NaN     NaN      NaN     None    NaN
# 39981      NaN     NaN      NaN     None    NaN
# 39982      NaN     NaN      NaN     None    NaN
# 39983      NaN     NaN      NaN     None    NaN
#
# [39984 rows x 35 columns]

# %% [markdown]
# ## 기술적 분석 지표 산출
# TA-Lib 라이브러리 사용
#
# - 추세 지표
#     - 5일 이평선 (MA5)
#     - 10일 이평선 (MA10)
#     - 20일 이평선 (MA20)
#     - 50일 이평선 (MA50)
#
# - 모멘텀 지표
#     - ADX (ADX)
#     - CCO (CCI)
#     - WILLIAMS%R (WIILR)
#
# - 시장 강도 지표
#     - RSI (RSI)

# %%
from QuantativeAnalysis import TechnicalAnalysis

ta = TechnicalAnalysis(fs_df)
ta_df = ta.get_TA()
ta_df
# Out:
#              DATE  NAME SECTOR   OPEN   HIGH    LOW  CLOSE   VOLUME  \
# 0      2017-10-10  현대건설     건설  38350  38700  37350  37650   436016
# 1      2017-10-11  현대건설     건설  37550  37800  37350  37450   396581
# 2      2017-10-12  현대건설     건설  37650  40150  37650  39900  1101121
# 3      2017-10-13  현대건설     건설  39900  40250  38900  39050   548941
# 4      2017-10-16  현대건설     건설  39200  39700  38600  39550   325083
# ...           ...   ...    ...    ...    ...    ...    ...      ...
# 39979  2021-02-22  계양전기  자동차부품   5030   5080   4900   4950   631718
# 39980  2021-02-23  계양전기  자동차부품   4895   4895   4710   4710   458610
# 39981  2021-02-24  계양전기  자동차부품   4735   4820   4560   4560   493301
# 39982  2021-02-25  계양전기  자동차부품   4655   4680   4555   4610   232616
# 39983  2021-02-26  계양전기  자동차부품   4480   4565   4380   4450   360085
#
#        1M_CLOSE_STD      PER  ...  SA_C_TO  ST_TO      MA5    MA10     MA20  \
# 0          0.000000     8.55  ...     None    NaN      NaN     NaN      NaN
# 1          0.000000     8.51  ...     None    NaN      NaN     NaN      NaN
# 2          0.000000     9.06  ...     None    NaN      NaN     NaN      NaN
# 3          0.000000     8.87  ...     None    NaN      NaN     NaN      NaN
# 4          0.000000     8.98  ...     None    NaN  38720.0     NaN      NaN
# ...             ...      ...  ...      ...    ...      ...     ...      ...
# 39979    204.184200  1237.50  ...     None    NaN   4932.0  4882.5  4765.25
# 39980    204.532394  1177.50  ...     None    NaN   4910.0  4843.5  4763.00
# 39981    204.231039  1140.00  ...     None    NaN   4850.0  4822.0  4750.00
# 39982    201.756747  1152.50  ...     None    NaN   4770.0  4813.0  4733.00
# 39983    210.200121  1112.50  ...     None    NaN   4656.0  4782.5  4715.75
#
#          MA50        ADX         CCI      WILLR        RSI
# 0         NaN        NaN         NaN        NaN        NaN
# 1         NaN        NaN         NaN        NaN        NaN
# 2         NaN        NaN         NaN        NaN        NaN
# 3         NaN        NaN         NaN        NaN        NaN
# 4         NaN        NaN         NaN        NaN        NaN
# ...       ...        ...         ...        ...        ...
# 39979  4498.7  38.965466   75.540249 -36.000000  56.609056
# 39980  4523.4  38.305748  -24.442703 -68.656716  49.631535
# 39981  4544.3  37.001256 -104.858300 -96.551724  45.829427
# 39982  4565.9  35.767020 -122.981187 -92.941176  47.279240
# 39983  4584.1  33.838167 -174.408384 -93.137255  43.286799
#
# [39984 rows x 43 columns]

# %%
# 결과를 pickle 파일로 저장
import datetime

now = datetime.datetime.now()
now_str = now.strftime('%m%d%H')

mask = (ta_df.DATE >= '2018-01-01') & (ta_df.DATE <= '2020-12-31')
result_df = ta_df[mask]
result_df.reset_index(drop=True, inplace=True)

result_df.to_pickle('./dataset/quantative_analysis_df_v{}.pkl'.format(now_str))
result_df
# Out:
#              DATE  NAME SECTOR   OPEN   HIGH    LOW  CLOSE    VOLUME  \
# 0      2018-01-02  현대건설     건설  36450  37400  36100  37150    649218
# 1      2018-01-03  현대건설     건설  36650  37000  36200  36300    482518
# 2      2018-01-04  현대건설     건설  36300  38400  36300  37950   1459930
# 3      2018-01-05  현대건설     건설  38200  38600  37300  38050    655891
# 4      2018-01-08  현대건설     건설  38000  38550  37400  38350    577188
# ...           ...   ...    ...    ...    ...    ...    ...       ...
# 35419  2020-12-23  계양전기  자동차부품   3935   5090   3795   5070  21751672
# 35420  2020-12-24  계양전기  자동차부품   4875   4900   4190   4205   6952461
# 35421  2020-12-28  계양전기  자동차부품   4260   4500   4055   4190   5965059
# 35422  2020-12-29  계양전기  자동차부품   4150   4275   4110   4170   1157499
# 35423  2020-12-30  계양전기  자동차부품   4195   4420   4150   4320   3522523
#
#        1M_CLOSE_STD      PER  ...   SA_C_TO     ST_TO      MA5     MA10  \
# 0        729.692760     8.44  ...  1.769322  2.227292  35810.0  35875.0
# 1        724.305702     8.24  ...  1.769322  2.227292  36090.0  35905.0
# 2        853.650292     8.62  ...  1.769322  2.227292  36610.0  36070.0
# 3        970.138032     8.64  ...  1.769322  2.227292  37150.0  36295.0
# 4       1136.080398     8.71  ...  1.769322  2.227292  37560.0  36520.0
# ...             ...      ...  ...       ...       ...      ...      ...
# 35419    397.543140  1267.50  ...  1.680578  1.783505   4216.0   3862.5
# 35420    413.160167  1051.25  ...  1.680578  1.783505   4352.0   3930.0
# 35421    442.223007  1047.50  ...  1.680578  1.783505   4351.0   3995.0
# 35422    441.859219  1042.50  ...  1.680578  1.783505   4311.0   4066.5
# 35423    447.954084  1080.00  ...  1.680578  1.783505   4391.0   4150.5
#
#            MA20     MA50        ADX         CCI      WILLR        RSI
# 0      35622.50  36807.0  12.044274  153.318078  -8.620690  57.307471
# 1      35702.50  36745.0  12.183271   92.292089 -37.931034  52.062683
# 2      35832.50  36703.0  13.522327  206.194190 -11.538462  59.761265
# 3      35897.50  36663.0  14.910828  188.419405 -13.414634  60.178666
# 4      36012.50  36630.0  16.200150  153.724271  -6.097561  61.469930
# ...         ...      ...        ...         ...        ...        ...
# 35419   3646.50   3341.6  48.845956  184.406324  -1.117318  77.888111
# 35420   3686.25   3359.5  50.136906  110.306029 -49.441341  58.095712
# 35421   3724.75   3378.2  50.663576   65.764523 -50.991501  57.821317
# 35422   3763.25   3398.6  51.152627   47.069541 -55.421687  57.431818
# 35423   3804.25   3422.9  51.805870   57.787871 -46.385542  59.628368
#
# [35424 rows x 43 columns]
